# %% [markdown]
# Let us say you are setting up a grocery store online and you are required to virtually set up items for shopping online, so shoppers can search for them using names of the aisle categories.  For instance eggs may be mapped to the aisle breakfast food or food.  The below file contains two columns : grocery items and aisle category.  How would you map each grocery item to an aisle name?  If an item does not have an appropriate category to map then you can use a generic "other" aisle category.  Think of an algorithm to solve this problem and write the steps of the algorithm clearly.   Is your approach efficient?  If so, argue how so?

# %%
import pandas as pd

# %%
input_filename = "Aisle-Mapping.xlsx"
output_filename = "Mapped-Aisles.xlsx"


aisle_data = pd.read_excel(input_filename)
print(aisle_data.head())
# Out:
#        Grocery ITEM Aisle Category
# 0    tropical fruit        Alcohol
# 1        whole milk           Baby
# 2         pip fruit         Bakery
# 3  other vegetables         Baking
# 4        whole milk      Beverages

# %%
aisle_data['Grocery ITEM'] = aisle_data['Grocery ITEM'].str.lower().str.strip()
aisle_data['Aisle Category'] = aisle_data['Aisle Category'].str.lower().str.strip()

# %%
aisle_map = dict()
for idx, row in aisle_data.iterrows():
    grocery_item = row.get('Grocery ITEM')
    aisle_category = row.get('Aisle Category')
    if pd.notna(grocery_item) and pd.notna(aisle_category) and grocery_item not in aisle_map.keys():
        aisle_map[grocery_item] = aisle_category

# %%
print(aisle_map)
# Out:
# {'tropical fruit': 'alcohol', 'whole milk': 'baby', 'pip fruit': 'bakery', 'other vegetables': 'baking', 'rolls/buns': 'candy', 'pot plants': 'cereal', 'citrus fruit': 'frozen', 'beef': 'garden', 'frankfurter': 'household', 'chicken': 'meat', 'butter': 'misc', 'fruit/vegetable juice': 'organic', 'packaged fruit/vegetables': 'pasta & grains', 'chocolate': 'personal care', 'specialty bar': 'pet', 'butter milk': 'seafood', 'bottled water': 'home & office', 'yogurt': 'nuts & seeds', 'sausage': 'deli dips & hummus', 'brown bread': 'frozen sandwiches', 'hamburger meat': 'health care & apothecary', 'root vegetables': 'deli bar & food service', 'pork': 'cheese', 'pastry': 'deli sides & meals', 'canned beer': 'grains', 'berries': 'pizza crust & sauce', 'coffee': 'rice side dishes', 'misc. beverages': 'stuffing mix', 'ham': 'kosher foods', 'turkey': 'misc international foods', 'curd cheese': 'spirits & mixers', 'red/blush wine': 'wine', 'frozen potato products': 'salami & lunch meats', 'flour': 'fresh fruits', 'sugar': 'fresh vegetables & herbs', 'frozen meals': 'nuts & dried fruits', 'herbs': 'deodorants', 'soda': 'hair care', 'detergent': 'pantyhose & apparel', 'grapes': 'personal & adult care', 'processed cheese': 'paper products', 'fish': 'paleo-friendly', 'sparkling wine': 'all sale', 'newspapers': 'o organics®', 'curd': 'overjoyed boutique™', 'pasta': 'bakery', 'popcorn': 'dry/baking goods', 'finished products': 'spirits', 'beverages': 'baby bath & skin care', 'bottled beer': 'canned seafood & fish', 'dessert': 'cookies', 'dog food': 'fish & shellfish', 'specialty chocolate': 'frozen', 'condensed milk': 'toys', 'cleaner': 'fresh vegetables', 'white wine': 'spices & herbs', 'meat': 'refrigerated items', 'ice cream': 'frozen', 'hard cheese': 'electronics & accessories', 'cream cheese': 'jewelry', 'liquor': 'sewing & fiber', 'pickled vegetables': 'cleaning', 'liquor (appetizer)': 'beauty', 'uht-milk': 'shop all savings', 'candy': 'flash deals', 'onions': 'all aapi everything', 'hair spray': 'adaptive at walmart', 'photo/film': 'patio & garden', 'domestic eggs': 'gas grills', 'margarine': 'soil', 'shopping bags': 'garage storage', 'salt': "women's plus", 'oil': 'men', 'whipped/sour cream': 'kids clothing', 'frozen vegetables': 'nintendo'}

# %%
def fill_aisle(row):
    if pd.isna(row['Aisle Category']) or row['Aisle Category'] == 'nan' or row['Aisle Category'] == '':
        mapped_category = aisle_map.get(row['Grocery ITEM'])
        if mapped_category is None or mapped_category == 'nan' or mapped_category == '':
            return 'other'
        return mapped_category
    return row['Aisle Category']

aisle_data['Aisle Category'] = aisle_data.apply(fill_aisle, axis=1)

# %%
for idx, row in aisle_data.iterrows():
    grocery_item = row.get('Grocery ITEM')
    aisle_category = row.get('Aisle Category')
    
    print(f"Mapped '{grocery_item}' to '{aisle_category}'")
# Out:
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'whole milk' to 'baby'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'other vegetables' to 'baking'
# Mapped 'whole milk' to 'beverages'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'other vegetables' to 'canned goods'
# Mapped 'pot plants' to 'cereal'
# Mapped 'whole milk' to 'condiments'
# Mapped 'tropical fruit' to 'dairy'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'beef' to 'garden'
# Mapped 'frankfurter' to 'household'
# Mapped 'chicken' to 'meat'
# Mapped 'butter' to 'misc'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'packaged fruit/vegetables' to 'pasta & grains'
# Mapped 'chocolate' to 'personal care'
# Mapped 'specialty bar' to 'pet'
# Mapped 'other vegetables' to 'produce'
# Mapped 'butter milk' to 'seafood'
# Mapped 'whole milk' to 'snacks'
# Mapped 'tropical fruit' to 'spices'
# Mapped 'tropical fruit' to 'international cuisine'
# Mapped 'bottled water' to 'home & office'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'other vegetables' to 'kitchen & dining'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'yogurt' to 'breakfast biscuits & toaster pastries'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'pork' to 'cheese'
# Mapped 'beef' to 'deli salads'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'fruit/vegetable juice' to 'dry beans & lentils'
# Mapped 'canned beer' to 'grains'
# Mapped 'root vegetables' to 'macaroni & cheese'
# Mapped 'citrus fruit' to 'pasta'
# Mapped 'sausage' to 'pasta sauce'
# Mapped 'tropical fruit' to 'pasta side dishes'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'canned beer' to 'potato side dishes'
# Mapped 'butter milk' to 'rice'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'pastry' to 'seeds'
# Mapped 'rolls/buns' to 'skillet dinners & sides'
# Mapped 'misc. beverages' to 'stuffing mix'
# Mapped 'root vegetables' to 'asian foods'
# Mapped 'sausage' to 'hispanic foods'
# Mapped 'canned beer' to 'indian middle east foods'
# Mapped 'ham' to 'kosher foods'
# Mapped 'turkey' to 'misc international foods'
# Mapped 'whole milk' to 'vegetarian foods'
# Mapped 'whole milk' to 'adult nutrition'
# Mapped 'packaged fruit/vegetables' to 'diabetes management'
# Mapped 'rolls/buns' to 'fitness equipment'
# Mapped 'ham' to 'herbal supplements'
# Mapped 'rolls/buns' to 'protein supplements'
# Mapped 'other vegetables' to 'specialty supplements'
# Mapped 'sausage' to 'vitamins & minerals'
# Mapped 'sausage' to 'weight management'
# Mapped 'frankfurter' to 'adult beverage'
# Mapped 'rolls/buns' to 'beer'
# Mapped 'whole milk' to 'spirits'
# Mapped 'curd cheese' to 'spirits & mixers'
# Mapped 'red/blush wine' to 'wine'
# Mapped 'sausage' to 'beef'
# Mapped 'tropical fruit' to 'chicken & turkey'
# Mapped 'red/blush wine' to 'fish & shellfish'
# Mapped 'whole milk' to 'lamb'
# Mapped 'frankfurter' to 'pork'
# Mapped 'whole milk' to 'prepared & frozen meat'
# Mapped 'frozen potato products' to 'salami & lunch meats'
# Mapped 'other vegetables' to 'sausage, hot dogs & bacon'
# Mapped 'citrus fruit' to 'bulk foods'
# Mapped 'flour' to 'fresh fruits'
# Mapped 'sugar' to 'fresh vegetables & herbs'
# Mapped 'frozen meals' to 'nuts & dried fruits'
# Mapped 'chocolate' to 'packaged produce'
# Mapped 'root vegetables' to 'antacid & digestive aids'
# Mapped 'root vegetables' to 'cold & allergy'
# Mapped 'herbs' to 'deodorants'
# Mapped 'bottled water' to 'eye & ear care'
# Mapped 'sausage' to 'family planning'
# Mapped 'coffee' to 'feminine care'
# Mapped 'pork' to 'first aid & medical care'
# Mapped 'berries' to 'foot care'
# Mapped 'soda' to 'hair care'
# Mapped 'berries' to 'health care & apothecary'
# Mapped 'fruit/vegetable juice' to 'nutrition solutions'
# Mapped 'citrus fruit' to 'oral hygiene'
# Mapped 'pork' to 'pain relief'
# Mapped 'detergent' to 'pantyhose & apparel'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'sausage' to 'shave needs'
# Mapped 'chicken' to 'skin care & cosmetics'
# Mapped 'whole milk' to 'trial size'
# Mapped 'citrus fruit' to 'vitamins & supplements'
# Mapped 'soda' to 'air fresheners & candles'
# Mapped 'sausage' to 'cleaners & supplies'
# Mapped 'frankfurter' to 'dish detergents'
# Mapped 'sausage' to 'fire logs & bbq needs'
# Mapped 'soda' to 'hardware & home needs'
# Mapped 'rolls/buns' to 'kitchen accessories'
# Mapped 'beef' to 'laundry'
# Mapped 'whole milk' to 'magazines, books & media'
# Mapped 'processed cheese' to 'paper products'
# Mapped 'tropical fruit' to 'plastic, foil & storage'
# Mapped 'frankfurter' to 'shoe care'
# Mapped 'packaged fruit/vegetables' to 'tableware & trash bags'
# Mapped 'whole milk' to 'cat care'
# Mapped 'berries' to 'dog care'
# Mapped 'citrus fruit' to 'small animal care'
# Mapped 'tropical fruit' to 'all diets'
# Mapped 'hamburger meat' to 'dairy-free'
# Mapped 'hamburger meat' to 'gluten-free'
# Mapped 'whole milk' to 'keto-friendly'
# Mapped 'fish' to 'paleo-friendly'
# Mapped 'frankfurter' to 'plant-based'
# Mapped 'packaged fruit/vegetables' to 'vegan'
# Mapped 'pastry' to 'all recipes'
# Mapped 'other vegetables' to 'carb-conscious'
# Mapped 'misc. beverages' to 'flexitarian'
# Mapped 'frankfurter' to 'pescatarian'
# Mapped 'sparkling wine' to 'all sale'
# Mapped 'specialty bar' to 'buy one get one free'
# Mapped 'sausage' to 'promo code deals'
# Mapped 'curd cheese' to 'sale prices'
# Mapped 'frankfurter' to 'chef's counter'
# Mapped 'whole milk' to 'lucerne®'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'berries' to 'open nature®'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'tropical fruit' to 'overjoyed™'
# Mapped 'soda' to 'primo taglio®'
# Mapped 'rolls/buns' to 'readymeals®'
# Mapped 'canned beer' to 'signature select®'
# Mapped 'canned beer' to 'soleil™'
# Mapped 'frankfurter' to 'value corner®'
# Mapped 'other vegetables' to 'waterfront bistro®'
# Mapped 'whole milk' to 'shop by food pairing'
# Mapped 'whole milk' to 'shop by region'
# Mapped 'citrus fruit' to 'shop by varietal'
# Mapped 'frankfurter' to 'type'
# Mapped 'frankfurter' to 'all vine & cellar'
# Mapped 'butter milk' to 'baby'
# Mapped 'hamburger meat' to 'baby care'
# Mapped 'pasta' to 'bakery'
# Mapped 'other vegetables' to 'baking'
# Mapped 'sausage' to 'beverages'
# Mapped 'rolls/buns' to 'breakfast'
# Mapped 'grapes' to 'canned/jarred goods'
# Mapped 'root vegetables' to 'cleaners'
# Mapped 'coffee' to 'dairy'
# Mapped 'popcorn' to 'dry/baking goods'
# Mapped 'whole milk' to 'frozen foods'
# Mapped 'tropical fruit' to 'meat'
# Mapped 'beef' to 'other'
# Mapped 'whole milk' to 'paper goods'
# Mapped 'frankfurter' to 'personal care'
# Mapped 'tropical fruit' to 'pet items'
# Mapped 'canned beer' to 'produce'
# Mapped 'finished products' to 'spirits'
# Mapped 'beverages' to 'baby bath & skin care'
# Mapped 'hamburger meat' to 'formula & baby food'
# Mapped 'whole milk' to 'coffee'
# Mapped 'finished products' to 'juice & smoothies'
# Mapped 'other vegetables' to 'bagels & muffins'
# Mapped 'ham' to 'bakery catering trays'
# Mapped 'other vegetables' to 'breakfast bars & bites'
# Mapped 'curd' to 'instant breakfast drink'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'curd' to 'noodles'
# Mapped 'whole milk' to 'jam,spreads & condiments'
# Mapped 'whole milk' to 'baking ingredients'
# Mapped 'dessert' to 'cookies'
# Mapped 'sausage' to 'eggs'
# Mapped 'other vegetables' to 'deli cheese'
# Mapped 'ham' to 'deli meat'
# Mapped 'other vegetables' to 'frozen meals & sides'
# Mapped 'other vegetables' to 'ice cream & novelties'
# Mapped 'soda' to 'fresh fruits'
# Mapped 'herbs' to 'packaged produce'
# Mapped 'frankfurter' to 'dry beans & lentils'
# Mapped 'rolls/buns' to 'potato side dishes'
# Mapped 'curd' to 'asian foods'
# Mapped 'frankfurter' to 'misc international foods'
# Mapped 'other vegetables' to 'beef'
# Mapped 'dog food' to 'fish & shellfish'
# Mapped 'specialty bar' to 'laundry'
# Mapped 'curd' to 'paper products'
# Mapped 'frankfurter' to 'hair care'
# Mapped 'soda' to 'skin care & cosmetics'
# Mapped 'beef' to 'cat care'
# Mapped 'canned beer' to 'small animal care'
# Mapped 'pork' to 'pantry'
# Mapped 'frankfurter' to 'beverage'
# Mapped 'sausage' to 'natural & organic'
# Mapped 'canned beer' to 'adult beverage'
# Mapped 'specialty chocolate' to 'frozen'
# Mapped 'curd' to 'health'
# Mapped 'canned beer' to 'vitamins & supplements'
# Mapped 'whole milk' to 'personal care'
# Mapped 'rolls/buns' to 'beauty'
# Mapped 'pork' to 'kitchen & dining'
# Mapped 'citrus fruit' to 'electronics'
# Mapped 'pot plants' to 'patio & grilling'
# Mapped 'rolls/buns' to 'cleaning & household'
# Mapped 'butter' to 'pets'
# Mapped 'condensed milk' to 'toys'
# Mapped 'sausage' to 'floral'
# Mapped 'whole milk' to 'vitacost'
# Mapped 'sausage' to 'murrays cheese'
# Mapped 'beverages' to 'home chef'
# Mapped 'beverages' to 'packaged foods'
# Mapped 'bottled water' to 'butcher'
# Mapped 'newspapers' to 'deli'
# Mapped 'cleaner' to 'fresh vegetables'
# Mapped 'sausage' to 'fresh fruits'
# Mapped 'newspapers' to 'canned foods'
# Mapped 'sausage' to 'sauces'
# Mapped 'misc. beverages' to 'various groceries'
# Mapped 'white wine' to 'spices & herbs'
# Mapped 'sausage' to 'oils/vinegars'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'frankfurter' to 'cheese'
# Mapped 'ice cream' to 'frozen'
# Mapped 'canned beer' to 'meat'
# Mapped 'tropical fruit' to 'seafood'
# Mapped 'meat' to 'baked goods'
# Mapped 'whole milk' to 'baking'
# Mapped 'sausage' to 'snacks'
# Mapped 'frankfurter' to 'personal care'
# Mapped 'meat' to 'medicine'
# Mapped 'root vegetables' to 'kitchen'
# Mapped 'root vegetables' to 'home & living'
# Mapped 'whole milk' to 'art & collectibles'
# Mapped 'citrus fruit' to 'craft supplies & tools'
# Mapped 'citrus fruit' to 'accessories'
# Mapped 'other vegetables' to 'bags & purses'
# Mapped 'citrus fruit' to 'bath & beauty'
# Mapped 'sausage' to 'books, movies & music'
# Mapped 'frankfurter' to 'clothing'
# Mapped 'hard cheese' to 'electronics & accessories'
# Mapped 'cream cheese' to 'jewelry'
# Mapped 'turkey' to 'paper & party supplies'
# Mapped 'pork' to 'pet supplies'
# Mapped 'whole milk' to 'shoes'
# Mapped 'rolls/buns' to 'toys & games'
# Mapped 'sausage' to 'weddings'
# Mapped 'ice cream' to 'gifts'
# Mapped 'liquor' to 'sewing & fiber'
# Mapped 'pip fruit' to 'storage & organization'
# Mapped 'root vegetables' to 'fiber arts'
# Mapped 'soda' to 'salad bar'
# Mapped 'soda' to 'check out'
# Mapped 'sausage' to 'office supplies'
# Mapped 'root vegetables' to 'seasonal'
# Mapped 'pork' to 'arts & crafts'
# Mapped 'pork' to 'party supplies'
# Mapped 'chocolate' to 'auto'
# Mapped 'fruit/vegetable juice' to 'sports & outdoors'
# Mapped 'pickled vegetables' to 'cleaning'
# Mapped 'bottled water' to 'home improvement'
# Mapped 'frankfurter' to 'garden'
# Mapped 'tropical fruit' to 'health & beauty'
# Mapped 'canned beer' to 'grocery'
# Mapped 'root vegetables' to 'home'
# Mapped 'meat' to 'fashion'
# Mapped 'frankfurter' to 'personal care'
# Mapped 'tropical fruit' to 'snacks & bev'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'citrus fruit' to 'bakery'
# Mapped 'hamburger meat' to 'clearance'
# Mapped 'chicken' to 'kitchen'
# Mapped 'chicken' to 'bath & shower'
# Mapped 'frankfurter' to 'bedding'
# Mapped 'canned beer' to 'mens'
# Mapped 'turkey' to 'boys'
# Mapped 'packaged fruit/vegetables' to 'intimates'
# Mapped 'pasta' to 'girls'
# Mapped 'citrus fruit' to 'womens'
# Mapped 'sausage' to 'furniture'
# Mapped 'whole milk' to 'laundry'
# Mapped 'canned beer' to 'baby'
# Mapped 'citrus fruit' to 'health'
# Mapped 'liquor (appetizer)' to 'beauty'
# Mapped 'citrus fruit' to 'hardware'
# Mapped 'sausage' to 'bread'
# Mapped 'chicken' to 'sports'
# Mapped 'hamburger meat' to 'frozen'
# Mapped 'sausage' to 'meat & seafood'
# Mapped 'beef' to 'fresh produce'
# Mapped 'citrus fruit' to 'savings & featured shops'
# Mapped 'uht-milk' to 'shop all savings'
# Mapped 'candy' to 'flash deals'
# Mapped 'newspapers' to 'new & trending'
# Mapped 'beef' to 'halloween'
# Mapped 'sausage' to 'tailgating'
# Mapped 'frankfurter' to 'back to school'
# Mapped 'canned beer' to 'back to college'
# Mapped 'bottled beer' to 'pride always'
# Mapped 'onions' to 'all aapi everything'
# Mapped 'tropical fruit' to 'behind every woman'
# Mapped 'bottled water' to 'black & unlimited'
# Mapped 'beef' to 'supporting veterans'
# Mapped 'sausage' to 'hispanic heritage'
# Mapped 'hair spray' to 'adaptive at walmart'
# Mapped 'chicken' to 'w+'
# Mapped 'pork' to 'everyday meals'
# Mapped 'ice cream' to 'home, furniture & appliances'
# Mapped 'meat' to 'shop all'
# Mapped 'other vegetables' to 'vacuums, steamers & floorcare'
# Mapped 'bottled water' to 'bath'
# Mapped 'tropical fruit' to 'savings'
# Mapped 'photo/film' to 'patio & garden'
# Mapped 'sausage' to 'patio sets'
# Mapped 'grapes' to 'conversation sets'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'rolls/buns' to 'charcoal'
# Mapped 'tropical fruit' to 'outdoor rugs'
# Mapped 'chicken' to 'outdoor cushions'
# Mapped 'frankfurter' to 'lawn mowers'
# Mapped 'berries' to 'pool chemicals'
# Mapped 'margarine' to 'soil'
# Mapped 'tropical fruit' to 'mulch'
# Mapped 'ham' to 'humidifiers'
# Mapped 'hamburger meat' to 'air quality'
# Mapped 'yogurt' to 'water purification'
# Mapped 'soda' to 'fasteners'
# Mapped 'yogurt' to 'fans'
# Mapped 'soda' to 'bathroom renovation'
# Mapped 'bottled water' to 'shower heads'
# Mapped 'sausage' to 'toilet seats & lids'
# Mapped 'citrus fruit' to 'light fixtures'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'newspapers' to 'adhesives & glues'
# Mapped 'frankfurter' to 'dehumidifiers'
# Mapped 'sausage' to 'air conditioners'
# Mapped 'frankfurter' to 'women'
# Mapped 'salt' to 'women's plus'
# Mapped 'oil' to 'men'
# Mapped 'curd' to 'young adult'
# Mapped 'other vegetables' to 'kids'
# Mapped 'citrus fruit' to 'baby & toddler'
# Mapped 'frankfurter' to 'dart blasters'
# Mapped 'root vegetables' to 'cars, drones & rc'
# Mapped 'tropical fruit' to 'kids bikes'
# Mapped 'beef' to 'all baby'
# Mapped 'berries' to 'baby days'
# Mapped 'canned beer' to 'toddler clothing'
# Mapped 'whipped/sour cream' to 'kids clothing'
# Mapped 'root vegetables' to 'video games'
# Mapped 'whole milk' to 'xbox'
# Mapped 'beef' to 'playstation'
# Mapped 'frozen vegetables' to 'nintendo'
# Mapped 'rolls/buns' to 'video game accessories'
# Mapped 'whole milk' to 'virtual reality'
# Mapped 'whole milk' to 'pharmacy, health & wellness'
# Mapped 'citrus fruit' to 'multipacks'
# Mapped 'pastry' to 'sun tanners'
# Mapped 'frankfurter' to 'premium beauty'
# Mapped 'tropical fruit' to 'suncare & tanning'
# Mapped 'frankfurter' to 'beauty box'
# Mapped 'berries' to 'pets and supplies'
# Mapped 'rolls/buns' to 'sporting goods'
# Mapped 'root vegetables' to 'other'
# Mapped 'yogurt' to 'piece goods, fabrics & crafts'
# Mapped 'other vegetables' to 'jewelry'
# Mapped 'berries' to 'media & gaming'
# Mapped 'berries' to 'horticulture and live plants'
# Mapped 'other vegetables' to 'hearing center'
# Mapped 'rolls/buns' to 'hearing center'
# Mapped 'ham' to 'cosmetics, fragrances, and skin care'
# Mapped 'whole milk' to 'concept stores'
# Mapped 'tropical fruit' to 'gasoline/fuel convenience stores'
# Mapped 'bottled water' to 'celebration and cards'
# Mapped 'butter milk' to 'furniture'
# Mapped 'newspapers' to 'electronics'
# Mapped 'coffee' to 'closet, storage, & organization'
# Mapped 'bottled beer' to 'large appliances...source personal care, health and beauty aids'
# Mapped 'onions' to 'stationery'
# Mapped 'hamburger meat' to 'wireless, wearables, cameras, and supplies'
# Mapped 'sausage' to 'toys'
# Mapped 'hard cheese' to 'electronics & accessories'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'onions' to 'all aapi everything'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'soda' to 'hair care'
# Mapped 'sliced cheese' to 'other'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'whole milk' to 'baby'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'dish cleaner' to 'other'
# Mapped 'other vegetables' to 'baking'
# Mapped 'whole milk' to 'baby'
# Mapped 'other vegetables' to 'baking'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'baking powder' to 'other'
# Mapped 'specialty bar' to 'pet'
# Mapped 'ice cream' to 'frozen'
# Mapped 'frankfurter' to 'household'
# Mapped 'canned beer' to 'grains'
# Mapped 'bottled water' to 'home & office'
# Mapped 'other vegetables' to 'baking'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'pork' to 'cheese'
# Mapped 'specialty cheese' to 'other'
# Mapped 'pork' to 'cheese'
# Mapped 'beef' to 'garden'
# Mapped 'other vegetables' to 'baking'
# Mapped 'chicken' to 'meat'
# Mapped 'soda' to 'hair care'
# Mapped 'whole milk' to 'baby'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'whole milk' to 'baby'
# Mapped 'soda' to 'hair care'
# Mapped 'bottled water' to 'home & office'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'salty snack' to 'other'
# Mapped 'bottled water' to 'home & office'
# Mapped 'chocolate' to 'personal care'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'bottled water' to 'home & office'
# Mapped 'onions' to 'all aapi everything'
# Mapped 'dessert' to 'cookies'
# Mapped 'beef' to 'garden'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'beef' to 'garden'
# Mapped 'soda' to 'hair care'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'pork' to 'cheese'
# Mapped 'soda' to 'hair care'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'beef' to 'garden'
# Mapped 'whole milk' to 'baby'
# Mapped 'pork' to 'cheese'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'bottled water' to 'home & office'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'herbs' to 'deodorants'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'instant food products' to 'other'
# Mapped 'specialty chocolate' to 'frozen'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'beef' to 'garden'
# Mapped 'whole milk' to 'baby'
# Mapped 'frankfurter' to 'household'
# Mapped 'frankfurter' to 'household'
# Mapped 'other vegetables' to 'baking'
# Mapped 'frankfurter' to 'household'
# Mapped 'whole milk' to 'baby'
# Mapped 'frankfurter' to 'household'
# Mapped 'other vegetables' to 'baking'
# Mapped 'bottled water' to 'home & office'
# Mapped 'pork' to 'cheese'
# Mapped 'bottled water' to 'home & office'
# Mapped 'other vegetables' to 'baking'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'whole milk' to 'baby'
# Mapped 'ice cream' to 'frozen'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'ham' to 'kosher foods'
# Mapped 'frankfurter' to 'household'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'bottled water' to 'home & office'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'dessert' to 'cookies'
# Mapped 'other vegetables' to 'baking'
# Mapped 'beverages' to 'baby bath & skin care'
# Mapped 'ham' to 'kosher foods'
# Mapped 'specialty bar' to 'pet'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'whole milk' to 'baby'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'pet care' to 'other'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'pork' to 'cheese'
# Mapped 'other vegetables' to 'baking'
# Mapped 'white wine' to 'spices & herbs'
# Mapped 'whole milk' to 'baby'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'sugar' to 'fresh vegetables & herbs'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'soda' to 'hair care'
# Mapped 'whole milk' to 'baby'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'white bread' to 'other'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'soda' to 'hair care'
# Mapped 'whole milk' to 'baby'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'pork' to 'cheese'
# Mapped 'other vegetables' to 'baking'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'sparkling wine' to 'all sale'
# Mapped 'bottled water' to 'home & office'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'packaged fruit/vegetables' to 'pasta & grains'
# Mapped 'other vegetables' to 'baking'
# Mapped 'soda' to 'hair care'
# Mapped 'whole milk' to 'baby'
# Mapped 'herbs' to 'deodorants'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'misc. beverages' to 'stuffing mix'
# Mapped 'female sanitary products' to 'other'
# Mapped 'soda' to 'hair care'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'soda' to 'hair care'
# Mapped 'white bread' to 'other'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'pork' to 'cheese'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'frankfurter' to 'household'
# Mapped 'frankfurter' to 'household'
# Mapped 'frankfurter' to 'household'
# Mapped 'other vegetables' to 'baking'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'whole milk' to 'baby'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'whole milk' to 'baby'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'onions' to 'all aapi everything'
# Mapped 'specialty chocolate' to 'frozen'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'photo/film' to 'patio & garden'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'canned beer' to 'grains'
# Mapped 'canned beer' to 'grains'
# Mapped 'other vegetables' to 'baking'
# Mapped 'canned beer' to 'grains'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'butter' to 'misc'
# Mapped 'other vegetables' to 'baking'
# Mapped 'whole milk' to 'baby'
# Mapped 'beef' to 'garden'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'soda' to 'hair care'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'frozen vegetables' to 'nintendo'
# Mapped 'beverages' to 'baby bath & skin care'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'canned beer' to 'grains'
# Mapped 'frozen vegetables' to 'nintendo'
# Mapped 'canned beer' to 'grains'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'canned beer' to 'grains'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'cling film/bags' to 'other'
# Mapped 'frankfurter' to 'household'
# Mapped 'whole milk' to 'baby'
# Mapped 'pork' to 'cheese'
# Mapped 'chicken' to 'meat'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'specialty bar' to 'pet'
# Mapped 'whipped/sour cream' to 'kids clothing'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'other vegetables' to 'baking'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'whole milk' to 'baby'
# Mapped 'frankfurter' to 'household'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'ham' to 'kosher foods'
# Mapped 'canned beer' to 'grains'
# Mapped 'canned beer' to 'grains'
# Mapped 'canned beer' to 'grains'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'pork' to 'cheese'
# Mapped 'soap' to 'other'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'beef' to 'garden'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'frozen chicken' to 'other'
# Mapped 'soda' to 'hair care'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'other vegetables' to 'baking'
# Mapped 'beef' to 'garden'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'bottled water' to 'home & office'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'pork' to 'cheese'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'beef' to 'garden'
# Mapped 'beef' to 'garden'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'beverages' to 'baby bath & skin care'
# Mapped 'beef' to 'garden'
# Mapped 'ham' to 'kosher foods'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'beef' to 'garden'
# Mapped 'beef' to 'garden'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'frankfurter' to 'household'
# Mapped 'beef' to 'garden'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'canned beer' to 'grains'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'other vegetables' to 'baking'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'frankfurter' to 'household'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'soda' to 'hair care'
# Mapped 'frankfurter' to 'household'
# Mapped 'chicken' to 'meat'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'whole milk' to 'baby'
# Mapped 'margarine' to 'soil'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'cream cheese' to 'jewelry'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'whole milk' to 'baby'
# Mapped 'frankfurter' to 'household'
# Mapped 'ham' to 'kosher foods'
# Mapped 'frankfurter' to 'household'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'whole milk' to 'baby'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'whole milk' to 'baby'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'bottled water' to 'home & office'
# Mapped 'beef' to 'garden'
# Mapped 'frankfurter' to 'household'
# Mapped 'chicken' to 'meat'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'pork' to 'cheese'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'whole milk' to 'baby'
# Mapped 'frankfurter' to 'household'
# Mapped 'beef' to 'garden'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'chicken' to 'meat'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'whole milk' to 'baby'
# Mapped 'detergent' to 'pantyhose & apparel'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'house keeping products' to 'other'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'beef' to 'garden'
# Mapped 'whole milk' to 'baby'
# Mapped 'pork' to 'cheese'
# Mapped 'other vegetables' to 'baking'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'frankfurter' to 'household'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'whole milk' to 'baby'
# Mapped 'bottled water' to 'home & office'
# Mapped 'frankfurter' to 'household'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'whole milk' to 'baby'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'chicken' to 'meat'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'frankfurter' to 'household'
# Mapped 'uht-milk' to 'shop all savings'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'canned beer' to 'grains'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'whipped/sour cream' to 'kids clothing'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'beverages' to 'baby bath & skin care'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'bottled water' to 'home & office'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'beef' to 'garden'
# Mapped 'spread cheese' to 'other'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'packaged fruit/vegetables' to 'pasta & grains'
# Mapped 'whole milk' to 'baby'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'onions' to 'all aapi everything'
# Mapped 'frankfurter' to 'household'
# Mapped 'beef' to 'garden'
# Mapped 'beef' to 'garden'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'chicken' to 'meat'
# Mapped 'canned beer' to 'grains'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'frankfurter' to 'household'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'beef' to 'garden'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'frankfurter' to 'household'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'beverages' to 'baby bath & skin care'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'ice cream' to 'frozen'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'other vegetables' to 'baking'
# Mapped 'dessert' to 'cookies'
# Mapped 'decalcifier' to 'other'
# Mapped 'canned beer' to 'grains'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'pork' to 'cheese'
# Mapped 'frankfurter' to 'household'
# Mapped 'pork' to 'cheese'
# Mapped 'frankfurter' to 'household'
# Mapped 'frozen dessert' to 'other'
# Mapped 'chicken' to 'meat'
# Mapped 'vinegar' to 'other'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'whole milk' to 'baby'
# Mapped 'pork' to 'cheese'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'frankfurter' to 'household'
# Mapped 'finished products' to 'spirits'
# Mapped 'onions' to 'all aapi everything'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'other vegetables' to 'baking'
# Mapped 'ham' to 'kosher foods'
# Mapped 'other vegetables' to 'baking'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'canned beer' to 'grains'
# Mapped 'ham' to 'kosher foods'
# Mapped 'packaged fruit/vegetables' to 'pasta & grains'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'whole milk' to 'baby'
# Mapped 'canned beer' to 'grains'
# Mapped 'chicken' to 'meat'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'pet care' to 'other'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'frankfurter' to 'household'
# Mapped 'chicken' to 'meat'
# Mapped 'frozen dessert' to 'other'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'frankfurter' to 'household'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'frankfurter' to 'household'
# Mapped 'frankfurter' to 'household'
# Mapped 'soda' to 'hair care'
# Mapped 'ice cream' to 'frozen'
# Mapped 'beef' to 'garden'
# Mapped 'whole milk' to 'baby'
# Mapped 'pork' to 'cheese'
# Mapped 'whole milk' to 'baby'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'pork' to 'cheese'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'canned beer' to 'grains'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'beef' to 'garden'
# Mapped 'chicken' to 'meat'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'cream cheese' to 'jewelry'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'specialty bar' to 'pet'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'frankfurter' to 'household'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'turkey' to 'misc international foods'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'whole milk' to 'baby'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'bottled water' to 'home & office'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'packaged fruit/vegetables' to 'pasta & grains'
# Mapped 'frankfurter' to 'household'
# Mapped 'nuts/prunes' to 'other'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'beef' to 'garden'
# Mapped 'whole milk' to 'baby'
# Mapped 'other vegetables' to 'baking'
# Mapped 'beef' to 'garden'
# Mapped 'fish' to 'paleo-friendly'
# Mapped 'other vegetables' to 'baking'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'chicken' to 'meat'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'frozen meals' to 'nuts & dried fruits'
# Mapped 'whipped/sour cream' to 'kids clothing'
# Mapped 'beef' to 'garden'
# Mapped 'chicken' to 'meat'
# Mapped 'chicken' to 'meat'
# Mapped 'beef' to 'garden'
# Mapped 'packaged fruit/vegetables' to 'pasta & grains'
# Mapped 'sugar' to 'fresh vegetables & herbs'
# Mapped 'frankfurter' to 'household'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'bottled water' to 'home & office'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'whole milk' to 'baby'
# Mapped 'ice cream' to 'frozen'
# Mapped 'frankfurter' to 'household'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'beef' to 'garden'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'sugar' to 'fresh vegetables & herbs'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'pork' to 'cheese'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'beef' to 'garden'
# Mapped 'pork' to 'cheese'
# Mapped 'white bread' to 'other'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'potato products' to 'other'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'chicken' to 'meat'
# Mapped 'chicken' to 'meat'
# Mapped 'fish' to 'paleo-friendly'
# Mapped 'canned beer' to 'grains'
# Mapped 'other vegetables' to 'baking'
# Mapped 'chicken' to 'meat'
# Mapped 'other vegetables' to 'baking'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'whole milk' to 'baby'
# Mapped 'beef' to 'garden'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'whole milk' to 'baby'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'whole milk' to 'baby'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'sliced cheese' to 'other'
# Mapped 'soda' to 'hair care'
# Mapped 'ham' to 'kosher foods'
# Mapped 'salty snack' to 'other'
# Mapped 'whole milk' to 'baby'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'soda' to 'hair care'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'bottled water' to 'home & office'
# Mapped 'packaged fruit/vegetables' to 'pasta & grains'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'ham' to 'kosher foods'
# Mapped 'pork' to 'cheese'
# Mapped 'beverages' to 'baby bath & skin care'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'whole milk' to 'baby'
# Mapped 'frankfurter' to 'household'
# Mapped 'soda' to 'hair care'
# Mapped 'soda' to 'hair care'
# Mapped 'frankfurter' to 'household'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'canned beer' to 'grains'
# Mapped 'frankfurter' to 'household'
# Mapped 'frankfurter' to 'household'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'frankfurter' to 'household'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'frozen fish' to 'other'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'beef' to 'garden'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'specialty chocolate' to 'frozen'
# Mapped 'sparkling wine' to 'all sale'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'onions' to 'all aapi everything'
# Mapped 'whole milk' to 'baby'
# Mapped 'photo/film' to 'patio & garden'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'other vegetables' to 'baking'
# Mapped 'whole milk' to 'baby'
# Mapped 'pork' to 'cheese'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'chicken' to 'meat'
# Mapped 'other vegetables' to 'baking'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'whole milk' to 'baby'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'hygiene articles' to 'other'
# Mapped 'ice cream' to 'frozen'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'whole milk' to 'baby'
# Mapped 'onions' to 'all aapi everything'
# Mapped 'finished products' to 'spirits'
# Mapped 'salt' to 'women's plus'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'other vegetables' to 'baking'
# Mapped 'chocolate' to 'personal care'
# Mapped 'ice cream' to 'frozen'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'frankfurter' to 'household'
# Mapped 'butter' to 'misc'
# Mapped 'other vegetables' to 'baking'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'uht-milk' to 'shop all savings'
# Mapped 'beef' to 'garden'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'pork' to 'cheese'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'frankfurter' to 'household'
# Mapped 'artif. sweetener' to 'other'
# Mapped 'frankfurter' to 'household'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'frankfurter' to 'household'
# Mapped 'whole milk' to 'baby'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'packaged fruit/vegetables' to 'pasta & grains'
# Mapped 'chicken' to 'meat'
# Mapped 'pork' to 'cheese'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'light bulbs' to 'other'
# Mapped 'cream cheese' to 'jewelry'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'other vegetables' to 'baking'
# Mapped 'chicken' to 'meat'
# Mapped 'ice cream' to 'frozen'
# Mapped 'pork' to 'cheese'
# Mapped 'pork' to 'cheese'
# Mapped 'onions' to 'all aapi everything'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'whipped/sour cream' to 'kids clothing'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'ice cream' to 'frozen'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'whole milk' to 'baby'
# Mapped 'whole milk' to 'baby'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'beef' to 'garden'
# Mapped 'pork' to 'cheese'
# Mapped 'turkey' to 'misc international foods'
# Mapped 'margarine' to 'soil'
# Mapped 'butter milk' to 'seafood'
# Mapped 'beef' to 'garden'
# Mapped 'bottled water' to 'home & office'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'whole milk' to 'baby'
# Mapped 'chocolate' to 'personal care'
# Mapped 'frankfurter' to 'household'
# Mapped 'whole milk' to 'baby'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'uht-milk' to 'shop all savings'
# Mapped 'onions' to 'all aapi everything'
# Mapped 'beef' to 'garden'
# Mapped 'pork' to 'cheese'
# Mapped 'canned beer' to 'grains'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'bottled water' to 'home & office'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'pork' to 'cheese'
# Mapped 'frankfurter' to 'household'
# Mapped 'ice cream' to 'frozen'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'canned vegetables' to 'other'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'whole milk' to 'baby'
# Mapped 'frankfurter' to 'household'
# Mapped 'dessert' to 'cookies'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'butter' to 'misc'
# Mapped 'frankfurter' to 'household'
# Mapped 'pork' to 'cheese'
# Mapped 'whole milk' to 'baby'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'frozen fish' to 'other'
# Mapped 'soda' to 'hair care'
# Mapped 'whole milk' to 'baby'
# Mapped 'pork' to 'cheese'
# Mapped 'whipped/sour cream' to 'kids clothing'
# Mapped 'frankfurter' to 'household'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'ham' to 'kosher foods'
# Mapped 'chewing gum' to 'other'
# Mapped 'beef' to 'garden'
# Mapped 'beef' to 'garden'
# Mapped 'other vegetables' to 'baking'
# Mapped 'frankfurter' to 'household'
# Mapped 'canned fish' to 'other'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'bottled water' to 'home & office'
# Mapped 'specialty cheese' to 'other'
# Mapped 'bottled water' to 'home & office'
# Mapped 'bottled water' to 'home & office'
# Mapped 'chicken' to 'meat'
# Mapped 'frankfurter' to 'household'
# Mapped 'chicken' to 'meat'
# Mapped 'chicken' to 'meat'
# Mapped 'butter' to 'misc'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'whipped/sour cream' to 'kids clothing'
# Mapped 'frankfurter' to 'household'
# Mapped 'beef' to 'garden'
# Mapped 'chicken' to 'meat'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'ice cream' to 'frozen'
# Mapped 'specialty chocolate' to 'frozen'
# Mapped 'frankfurter' to 'household'
# Mapped 'pork' to 'cheese'
# Mapped 'uht-milk' to 'shop all savings'
# Mapped 'uht-milk' to 'shop all savings'
# Mapped 'cookware' to 'other'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'frankfurter' to 'household'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'ham' to 'kosher foods'
# Mapped 'ham' to 'kosher foods'
# Mapped 'bottled water' to 'home & office'
# Mapped 'popcorn' to 'dry/baking goods'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'frankfurter' to 'household'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'soda' to 'hair care'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'red/blush wine' to 'wine'
# Mapped 'uht-milk' to 'shop all savings'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'semi-finished bread' to 'other'
# Mapped 'whole milk' to 'baby'
# Mapped 'cat food' to 'other'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'ham' to 'kosher foods'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'ice cream' to 'frozen'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'finished products' to 'spirits'
# Mapped 'dessert' to 'cookies'
# Mapped 'sparkling wine' to 'all sale'
# Mapped 'other vegetables' to 'baking'
# Mapped 'misc. beverages' to 'stuffing mix'
# Mapped 'other vegetables' to 'baking'
# Mapped 'misc. beverages' to 'stuffing mix'
# Mapped 'dessert' to 'cookies'
# Mapped 'frankfurter' to 'household'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'meat' to 'refrigerated items'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'onions' to 'all aapi everything'
# Mapped 'beef' to 'garden'
# Mapped 'pip fruit' to 'bakery'
# Mapped 'ham' to 'kosher foods'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'other vegetables' to 'baking'
# Mapped 'pork' to 'cheese'
# Mapped 'bathroom cleaner' to 'other'
# Mapped 'ham' to 'kosher foods'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'photo/film' to 'patio & garden'
# Mapped 'dessert' to 'cookies'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'soda' to 'hair care'
# Mapped 'chewing gum' to 'other'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'pork' to 'cheese'
# Mapped 'turkey' to 'misc international foods'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'pork' to 'cheese'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'grapes' to 'personal & adult care'
# Mapped 'other vegetables' to 'baking'
# Mapped 'pot plants' to 'cereal'
# Mapped 'bottled water' to 'home & office'
# Mapped 'prosecco' to 'other'
# Mapped 'uht-milk' to 'shop all savings'
# Mapped 'bottled water' to 'home & office'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'specialty chocolate' to 'frozen'
# Mapped 'beef' to 'garden'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'beef' to 'garden'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'chicken' to 'meat'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'canned beer' to 'grains'
# Mapped 'soda' to 'hair care'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'whole milk' to 'baby'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'frankfurter' to 'household'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'ham' to 'kosher foods'
# Mapped 'other vegetables' to 'baking'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'pork' to 'cheese'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'other vegetables' to 'baking'
# Mapped 'pork' to 'cheese'
# Mapped 'chicken' to 'meat'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'beef' to 'garden'
# Mapped 'frankfurter' to 'household'
# Mapped 'frankfurter' to 'household'
# Mapped 'beef' to 'garden'
# Mapped 'ham' to 'kosher foods'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'pork' to 'cheese'
# Mapped 'condensed milk' to 'toys'
# Mapped 'chicken' to 'meat'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'chicken' to 'meat'
# Mapped 'finished products' to 'spirits'
# Mapped 'pork' to 'cheese'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'bottled water' to 'home & office'
# Mapped 'cling film/bags' to 'other'
# Mapped 'other vegetables' to 'baking'
# Mapped 'whole milk' to 'baby'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'frankfurter' to 'household'
# Mapped 'frozen potato products' to 'salami & lunch meats'
# Mapped 'frankfurter' to 'household'
# Mapped 'frankfurter' to 'household'
# Mapped 'chicken' to 'meat'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'hamburger meat' to 'health care & apothecary'
# Mapped 'chicken' to 'meat'
# Mapped 'pork' to 'cheese'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'bottled water' to 'home & office'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'frozen potato products' to 'salami & lunch meats'
# Mapped 'frankfurter' to 'household'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'tropical fruit' to 'alcohol'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'turkey' to 'misc international foods'
# Mapped 'soda' to 'hair care'
# Mapped 'canned beer' to 'grains'
# Mapped 'canned beer' to 'grains'
# Mapped 'sausage' to 'deli dips & hummus'
# Mapped 'pork' to 'cheese'
# Mapped 'instant food products' to 'other'
# Mapped 'frankfurter' to 'household'
# Mapped 'oil' to 'men'
# Mapped 'chicken' to 'meat'
# Mapped 'beef' to 'garden'
# Mapped 'dessert' to 'cookies'
# Mapped 'pork' to 'cheese'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'chicken' to 'meat'
# Mapped 'whipped/sour cream' to 'kids clothing'
# Mapped 'frankfurter' to 'household'
# Mapped 'frankfurter' to 'household'
# Mapped 'liver loaf' to 'other'
# Mapped 'pork' to 'cheese'
# Mapped 'frankfurter' to 'household'
# Mapped 'pork' to 'cheese'
# Mapped 'pork' to 'cheese'
# Mapped 'soda' to 'hair care'
# Mapped 'root vegetables' to 'deli bar & food service'
# Mapped 'whipped/sour cream' to 'kids clothing'
# Mapped 'chocolate' to 'personal care'
# Mapped 'whole milk' to 'baby'
# Mapped 'pork' to 'cheese'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'citrus fruit' to 'frozen'
# Mapped 'soda' to 'hair care'
# Mapped 'cream cheese' to 'jewelry'
# Mapped 'soda' to 'hair care'
# Mapped 'chicken' to 'meat'
# Mapped 'frozen fish' to 'other'
# Mapped 'sausage' to 'deli dips & hummus'
# ...
# Mapped 'rolls/buns' to 'candy'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'detergent' to 'pantyhose & apparel'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'canned beer' to 'grains'
# Mapped 'other vegetables' to 'baking'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'pot plants' to 'cereal'
# Mapped 'flower (seeds)' to 'other'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'dish cleaner' to 'other'
# Mapped 'canned beer' to 'grains'
# Mapped 'long life bakery product' to 'other'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'bottled water' to 'home & office'
# Mapped 'cereals' to 'other'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'sugar' to 'fresh vegetables & herbs'
# Mapped 'soda' to 'hair care'
# Mapped 'male cosmetics' to 'other'
# Mapped 'cling film/bags' to 'other'
# Mapped 'sparkling wine' to 'all sale'
# Mapped 'napkins' to 'other'
# Mapped 'waffles' to 'other'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'white bread' to 'other'
# Mapped 'napkins' to 'other'
# Mapped 'hair spray' to 'adaptive at walmart'
# Mapped 'candles' to 'other'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'instant coffee' to 'other'
# Mapped 'seasonal products' to 'other'
# Mapped 'butter' to 'misc'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'house keeping products' to 'other'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'candy' to 'flash deals'
# Mapped 'cream cheese' to 'jewelry'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'ready soups' to 'other'
# Mapped 'bottled water' to 'home & office'
# Mapped 'canned vegetables' to 'other'
# Mapped 'semi-finished bread' to 'other'
# Mapped 'red/blush wine' to 'wine'
# Mapped 'male cosmetics' to 'other'
# Mapped 'bottled water' to 'home & office'
# Mapped 'napkins' to 'other'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'dishes' to 'other'
# Mapped 'soda' to 'hair care'
# Mapped 'instant coffee' to 'other'
# Mapped 'salty snack' to 'other'
# Mapped 'specialty chocolate' to 'frozen'
# Mapped 'cooking chocolate' to 'other'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'margarine' to 'soil'
# Mapped 'frozen dessert' to 'other'
# Mapped 'long life bakery product' to 'other'
# Mapped 'candy' to 'flash deals'
# Mapped 'bottled water' to 'home & office'
# Mapped 'salty snack' to 'other'
# Mapped 'chocolate marshmallow' to 'other'
# Mapped 'dental care' to 'other'
# Mapped 'dishes' to 'other'
# Mapped 'canned vegetables' to 'other'
# Mapped 'hygiene articles' to 'other'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'napkins' to 'other'
# Mapped 'margarine' to 'soil'
# Mapped 'margarine' to 'soil'
# Mapped 'seasonal products' to 'other'
# Mapped 'cake bar' to 'other'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'soda' to 'hair care'
# Mapped 'soda' to 'hair care'
# Mapped 'whole milk' to 'baby'
# Mapped 'bottled water' to 'home & office'
# Mapped 'candy' to 'flash deals'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'roll products' to 'other'
# Mapped 'liquor' to 'sewing & fiber'
# Mapped 'brandy' to 'other'
# Mapped 'chocolate marshmallow' to 'other'
# Mapped 'bottled water' to 'home & office'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'hard cheese' to 'electronics & accessories'
# Mapped 'frozen vegetables' to 'nintendo'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'salt' to 'women's plus'
# Mapped 'canned vegetables' to 'other'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'photo/film' to 'patio & garden'
# Mapped 'cream cheese' to 'jewelry'
# Mapped 'whipped/sour cream' to 'kids clothing'
# Mapped 'processed cheese' to 'paper products'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'skin care' to 'other'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'waffles' to 'other'
# Mapped 'oil' to 'men'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'pickled vegetables' to 'cleaning'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'frozen vegetables' to 'nintendo'
# Mapped 'candy' to 'flash deals'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'cleaner' to 'fresh vegetables'
# Mapped 'popcorn' to 'dry/baking goods'
# Mapped 'candles' to 'other'
# Mapped 'photo/film' to 'patio & garden'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'cling film/bags' to 'other'
# Mapped 'house keeping products' to 'other'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'napkins' to 'other'
# Mapped 'dishes' to 'other'
# Mapped 'butter' to 'misc'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'uht-milk' to 'shop all savings'
# Mapped 'whole milk' to 'baby'
# Mapped 'dishes' to 'other'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'uht-milk' to 'shop all savings'
# Mapped 'whole milk' to 'baby'
# Mapped 'chewing gum' to 'other'
# Mapped 'bottled water' to 'home & office'
# Mapped 'hygiene articles' to 'other'
# Mapped 'margarine' to 'soil'
# Mapped 'hygiene articles' to 'other'
# Mapped 'honey' to 'other'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'canned fish' to 'other'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'oil' to 'men'
# Mapped 'instant food products' to 'other'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'specialty bar' to 'pet'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'beverages' to 'baby bath & skin care'
# Mapped 'seasonal products' to 'other'
# Mapped 'misc. beverages' to 'stuffing mix'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'sliced cheese' to 'other'
# Mapped 'whole milk' to 'baby'
# Mapped 'detergent' to 'pantyhose & apparel'
# Mapped 'sliced cheese' to 'other'
# Mapped 'cream cheese' to 'jewelry'
# Mapped 'bottled water' to 'home & office'
# Mapped 'bathroom cleaner' to 'other'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'white bread' to 'other'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'pet care' to 'other'
# Mapped 'frozen vegetables' to 'nintendo'
# Mapped 'cake bar' to 'other'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'cling film/bags' to 'other'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'processed cheese' to 'paper products'
# Mapped 'canned fish' to 'other'
# Mapped 'cake bar' to 'other'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'bottled water' to 'home & office'
# Mapped 'curd cheese' to 'spirits & mixers'
# Mapped 'instant food products' to 'other'
# Mapped 'chocolate' to 'personal care'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'chocolate' to 'personal care'
# Mapped 'waffles' to 'other'
# Mapped 'specialty chocolate' to 'frozen'
# Mapped 'whisky' to 'other'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'dessert' to 'cookies'
# Mapped 'napkins' to 'other'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'chocolate' to 'personal care'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'butter' to 'misc'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'soda' to 'hair care'
# Mapped 'baking powder' to 'other'
# Mapped 'pet care' to 'other'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'cleaner' to 'fresh vegetables'
# Mapped 'dental care' to 'other'
# Mapped 'nut snack' to 'other'
# Mapped 'chocolate' to 'personal care'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'hygiene articles' to 'other'
# Mapped 'frozen vegetables' to 'nintendo'
# Mapped 'artif. sweetener' to 'other'
# Mapped 'oil' to 'men'
# Mapped 'specialty chocolate' to 'frozen'
# Mapped 'chocolate' to 'personal care'
# Mapped 'frozen vegetables' to 'nintendo'
# Mapped 'margarine' to 'soil'
# Mapped 'uht-milk' to 'shop all savings'
# Mapped 'candy' to 'flash deals'
# Mapped 'napkins' to 'other'
# Mapped 'vinegar' to 'other'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'chocolate' to 'personal care'
# Mapped 'bottled water' to 'home & office'
# Mapped 'whole milk' to 'baby'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'frozen fish' to 'other'
# Mapped 'soda' to 'hair care'
# Mapped 'dish cleaner' to 'other'
# Mapped 'herbs' to 'deodorants'
# Mapped 'canned vegetables' to 'other'
# Mapped 'long life bakery product' to 'other'
# Mapped 'margarine' to 'soil'
# Mapped 'semi-finished bread' to 'other'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'waffles' to 'other'
# Mapped 'bottled water' to 'home & office'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'long life bakery product' to 'other'
# Mapped 'baking powder' to 'other'
# Mapped 'napkins' to 'other'
# Mapped 'napkins' to 'other'
# Mapped 'oil' to 'men'
# Mapped 'whipped/sour cream' to 'kids clothing'
# Mapped 'sugar' to 'fresh vegetables & herbs'
# Mapped 'cling film/bags' to 'other'
# Mapped 'butter' to 'misc'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'beverages' to 'baby bath & skin care'
# Mapped 'oil' to 'men'
# Mapped 'long life bakery product' to 'other'
# Mapped 'ice cream' to 'frozen'
# Mapped 'napkins' to 'other'
# Mapped 'soda' to 'hair care'
# Mapped 'flour' to 'fresh fruits'
# Mapped 'waffles' to 'other'
# Mapped 'cleaner' to 'fresh vegetables'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'bottled water' to 'home & office'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'sliced cheese' to 'other'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'bottled water' to 'home & office'
# Mapped 'frozen potato products' to 'salami & lunch meats'
# Mapped 'rice' to 'other'
# Mapped 'margarine' to 'soil'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'softener' to 'other'
# Mapped 'soda' to 'hair care'
# Mapped 'sliced cheese' to 'other'
# Mapped 'popcorn' to 'dry/baking goods'
# Mapped 'specialty cheese' to 'other'
# Mapped 'misc. beverages' to 'stuffing mix'
# Mapped 'instant food products' to 'other'
# Mapped 'bottled water' to 'home & office'
# Mapped 'dessert' to 'cookies'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'hygiene articles' to 'other'
# Mapped 'honey' to 'other'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'cereals' to 'other'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'sliced cheese' to 'other'
# Mapped 'red/blush wine' to 'wine'
# Mapped 'oil' to 'men'
# Mapped 'cream cheese' to 'jewelry'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'other vegetables' to 'baking'
# Mapped 'candy' to 'flash deals'
# Mapped 'mayonnaise' to 'other'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'seasonal products' to 'other'
# Mapped 'processed cheese' to 'paper products'
# Mapped 'soft cheese' to 'other'
# Mapped 'brandy' to 'other'
# Mapped 'tea' to 'other'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'jam' to 'other'
# Mapped 'syrup' to 'other'
# Mapped 'curd cheese' to 'spirits & mixers'
# Mapped 'sliced cheese' to 'other'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'tidbits' to 'other'
# Mapped 'specialty chocolate' to 'frozen'
# Mapped 'salty snack' to 'other'
# Mapped 'jam' to 'other'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'popcorn' to 'dry/baking goods'
# Mapped 'flower (seeds)' to 'other'
# Mapped 'white bread' to 'other'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'bottled water' to 'home & office'
# Mapped 'butter' to 'misc'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'waffles' to 'other'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'margarine' to 'soil'
# Mapped 'salty snack' to 'other'
# Mapped 'frozen vegetables' to 'nintendo'
# Mapped 'oil' to 'men'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'hygiene articles' to 'other'
# Mapped 'whole milk' to 'baby'
# Mapped 'dish cleaner' to 'other'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'hygiene articles' to 'other'
# Mapped 'curd' to 'overjoyed boutique™'
# Mapped 'coffee' to 'rice side dishes'
# Mapped 'frozen vegetables' to 'nintendo'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'vinegar' to 'other'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'whole milk' to 'baby'
# Mapped 'potato products' to 'other'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'frozen fish' to 'other'
# Mapped 'cream cheese' to 'jewelry'
# Mapped 'whole milk' to 'baby'
# Mapped 'dishes' to 'other'
# Mapped 'baking powder' to 'other'
# Mapped 'white wine' to 'spices & herbs'
# Mapped 'pickled vegetables' to 'cleaning'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'decalcifier' to 'other'
# Mapped 'dish cleaner' to 'other'
# Mapped 'candy' to 'flash deals'
# Mapped 'chocolate' to 'personal care'
# Mapped 'seasonal products' to 'other'
# Mapped 'waffles' to 'other'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'pot plants' to 'cereal'
# Mapped 'white bread' to 'other'
# Mapped 'seasonal products' to 'other'
# Mapped 'whole milk' to 'baby'
# Mapped 'whole milk' to 'baby'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'bottled water' to 'home & office'
# Mapped 'waffles' to 'other'
# Mapped 'bottled beer' to 'canned seafood & fish'
# Mapped 'curd cheese' to 'spirits & mixers'
# Mapped 'uht-milk' to 'shop all savings'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'margarine' to 'soil'
# Mapped 'canned fish' to 'other'
# Mapped 'frozen vegetables' to 'nintendo'
# Mapped 'cling film/bags' to 'other'
# Mapped 'cream cheese' to 'jewelry'
# Mapped 'white bread' to 'other'
# Mapped 'white wine' to 'spices & herbs'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'frozen fish' to 'other'
# Mapped 'bottled water' to 'home & office'
# Mapped 'berries' to 'pizza crust & sauce'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'hygiene articles' to 'other'
# Mapped 'processed cheese' to 'paper products'
# Mapped 'newspapers' to 'o organics®'
# Mapped 'flour' to 'fresh fruits'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'napkins' to 'other'
# Mapped 'domestic eggs' to 'gas grills'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'soda' to 'hair care'
# Mapped 'baking powder' to 'other'
# Mapped 'long life bakery product' to 'other'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'salty snack' to 'other'
# Mapped 'yogurt' to 'nuts & seeds'
# Mapped 'dessert' to 'cookies'
# Mapped 'canned fish' to 'other'
# Mapped 'long life bakery product' to 'other'
# Mapped 'brown bread' to 'frozen sandwiches'
# Mapped 'hygiene articles' to 'other'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'soda' to 'hair care'
# Mapped 'napkins' to 'other'
# Mapped 'specialty bar' to 'pet'
# Mapped 'napkins' to 'other'
# Mapped 'shopping bags' to 'garage storage'
# Mapped 'instant coffee' to 'other'
# Mapped 'beverages' to 'baby bath & skin care'
# Mapped 'bottled water' to 'home & office'
# Mapped 'zwieback' to 'other'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'instant food products' to 'other'
# Mapped 'long life bakery product' to 'other'
# Mapped 'whipped/sour cream' to 'kids clothing'
# Mapped 'salt' to 'women's plus'
# Mapped 'potato products' to 'other'
# Mapped 'whole milk' to 'baby'
# Mapped 'frozen vegetables' to 'nintendo'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'sugar' to 'fresh vegetables & herbs'
# Mapped 'chocolate' to 'personal care'
# Mapped 'sugar' to 'fresh vegetables & herbs'
# Mapped 'pastry' to 'deli sides & meals'
# Mapped 'cling film/bags' to 'other'
# Mapped 'waffles' to 'other'
# Mapped 'instant food products' to 'other'
# Mapped 'bottled water' to 'home & office'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'rolls/buns' to 'candy'
# Mapped 'long life bakery product' to 'other'
# Mapped 'oil' to 'men'
# Mapped 'sliced cheese' to 'other'
# Mapped 'candy' to 'flash deals'
# Mapped 'cake bar' to 'other'
# Mapped 'fruit/vegetable juice' to 'organic'
# Mapped 'cat food' to 'other'

# %%
aisle_data.to_excel(output_filename, index=False)
